# %% [markdown]
# # Bölüm 7 — Regresyon — Öğrenci Çalışma Defteri
#
# Önce `VERI.md` ve `GOREVLER.md` dosyalarını okuyun. TODO hücrelerini siz tamamlayın; sonuçları en sonda `COZUMLER.md`, `beklenen.json` ve `RAPORLAMA.md` ile kontrol edin.

# %%
from pathlib import Path
import numpy as np, pandas as pd, matplotlib.pyplot as plt
import statsmodels.api as sm
HERE=Path.cwd()
df=pd.read_csv(HERE/"veri.csv")
ana=df.iloc[:60].copy()
display(ana.head())

# %% [markdown]
# ## Görevler
# 1. G3 ~ G1 basit OLS modelini kurun.
# 2. Katsayıları, R², RMSE ve %95 GA'yı raporlayın.
# 3. G1=12 için ortalama yanıt GA ve bireysel tahmin aralığını karşılaştırın.
# 4. Kaldıraç ve Cook uzaklığıyla etkili gözlemleri inceleyin; otomatik silmeyin.
# 5. HC3 ve LOOCV sonuçlarını ana modele ek duyarlılık olarak karşılaştırın.

# %%
# TODO: X'e sabit terim ekleyip OLS modelini kurun.
# model = sm.OLS(...).fit()

# %%
# TODO: saçılım + regresyon doğrusu ve artık/tanı grafiği üretin.

# %% [markdown]
# ## Akademik raporlama
# **Model:** …
# **Katsayı ve %95 GA:** …
# **R² / RMSE:** …
# **Tahmin:** …
# **Tanı ve duyarlılık:** …
# **Nedensellik/genelleme sınırı:** …

# %% [markdown]
# Kontrol sırası: `GOREVLER.md` → `COZUMLER.md` → `beklenen.json` → `RAPORLAMA.md`. `analiz.py`/`analiz.R` yalnız son kontroldür.
