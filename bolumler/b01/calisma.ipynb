# %% [markdown]
# # Bölüm 1 — İstatistiksel Düşünme: Sorudan Kanıta — Öğrenci Çalışma Defteri
#
# Önce `VERI.md` ve `GOREVLER.md` dosyalarını okuyun. `TODO` hücrelerini siz tamamlayın; en sonda `COZUMLER.md`, `beklenen.json` ve `RAPORLAMA.md` ile kontrol edin.
#
# **Akış:** Araştırma sorusu → Anakütle/çerçeve → Birim → Veri → Değişken → Özet/Grafik → Kanıt → Sınırlılık → Raporlama

# %% [markdown]
# ## 1. Hazırlık

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
HERE = Path.cwd()
print("Klasör:", HERE)

# %% [markdown]
# ## 2. Gerçek veriyle ilk karşılaşma
# Veriyi değiştirmeden önce satır sayısını, sütunları, eksik değerleri ve olası analiz birimini inceleyin.

# %%
df = pd.read_csv(HERE / "veri.csv")
display(df.head())
print("Boyut:", df.shape)
display(df.isna().sum().to_frame("eksik"))
print("Okul düzeyleri:", sorted(df["school"].unique()))

# %% [markdown]
# ## 3. Birim ve değişken
# Kendi cümlelerinizle yazın: Bir satır neyi temsil ediyor? G1 ve G3 neden iki bağımsız kişi değildir? `school`, `G1`, `G3` ve `fark_G3_G1` değişkenlerini nasıl sınıflandırırsınız?
#
# Ek düşünme: Bu veri uzun biçime çevrilip 160 satır olursa bağımsız öğrenci sayısı neden 160 olmaz?

# %%
# TODO: Değişkenler için uygun bir veri sözlüğü tablosu oluşturun.

# %% [markdown]
# ## 4. Frekans, yüzde ve payda
# G3 için frekans ve yüzde tablosu oluşturun. Yüzdelerin hangi payda ile hesaplandığını açıkça belirtin.

# %%
# TODO: G3 frekans ve yüzde tablosunu oluşturun.

# %% [markdown]
# ## 5. Sistematik örnekleme öğretim örneği
# Kitaptaki örneği yeniden üretin: N=80, n=10 olduğundan sistematik aralık j=8'dir. Gösterim için başlangıç r=3 sabitlenmiştir. 3. kayıttan başlayıp sekizer kayıt arayla seçim yapın; seçilen satırları, n değerini ve G1/G3 ortalamalarını bulun. Başlangıç 3'ün burada rastgele çekilmiş olmadığını ve bu işlemin ilk 80 kaydı temsili hale getirmediğini açıklayın.

# %%
# TODO: başlangıç=3, aralık=8 sistematik seçim örneğini kurun.
# Beklenen sıra: 3, 11, 19, 27, 35, 43, 51, 59, 67, 75

# %% [markdown]
# ## 6. Parametre mi, istatistik mi?
# Yalnız bu örnekleme alıştırması için 80 kaydı kapalı bir öğretim anakütlesi kabul edin. G3 toplamını ve ortalamasını hesaplayın. Ardından seçtiğiniz 10 kaydın G3 ortalamasıyla karşılaştırın. Neden 12.6375 bütün Portekiz öğrencilerinin parametresi değildir?

# %%
# TODO: 80 kaydın G3 toplam/ortalamasını ve 10 kayıtlık sistematik örneğin ortalamasını karşılaştırın.

# %% [markdown]
# ## 7. Grafik seçimi
# G3 dağılımını göstermek için uygun bir grafik üretin. Ardından G1 ile G3 arasındaki birlikte değişimi göstermek için hangi grafiğin uygun olduğunu düşünün.

# %%
# TODO: En az bir uygun grafik üretin.
# plt.show()

# %% [markdown]
# ## 8. Kanıt ve genelleme sınırı
# Aşağıdaki soruları yanıtlayın:
# 1. Bu 80 kayıt hangi hedef anakütleyi temsil ediyor?
# 2. Rastgelelik ile temsiliyet aynı şey midir?
# 3. G3 ortalamasından 'öğrenciler başarılıdır' sonucu çıkarılabilir mi?
# 4. G1 ile G3 arasındaki ilişki nedensel etki olarak yorumlanabilir mi?

# %% [markdown]
# ### Akademik raporlama taslağım
#
# **Araştırma sorusu:** …
#
# **Veri kaynağı:** …
#
# **Analiz birimi:** …
#
# **Seçim/örnekleme sınırı:** …
#
# **Temel betimsel bulgu:** …
#
# **Grafik seçimi:** …
#
# **Genelleme sınırı:** …
#
# **Yeniden üretim bilgisi:** …

# %% [markdown]
# ## 9. Kontrol
# 1. `GOREVLER.md`
# 2. `COZUMLER.md`
# 3. `beklenen.json`
# 4. `RAPORLAMA.md`
# 5. `analiz.py` yalnız son teknik kontrol içindir.
