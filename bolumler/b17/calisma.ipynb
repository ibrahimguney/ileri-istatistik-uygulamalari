# %% [markdown]
# # Bölüm 17 — Kovaryans Analizi — Öğrenci Çalışma Defteri
#
# Önce `VERI.md` ve `GOREVLER.md` dosyalarını okuyun. Bu veri klasik ön-test kovaryatlı bir ANCOVA tasarımı değildir; dose uygulanan koşuldur. Model biçimini ve ortak desteği açıkça inceleyin.

# %%
from pathlib import Path
import numpy as np, pandas as pd, matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
HERE=Path.cwd()
df=pd.read_csv(HERE/"ToothGrowth.csv")
display(df.head())

# %% [markdown]
# ## Görevler
# 1. dose'u 1 mg çevresinde merkezleyip ortak eğimli `len ~ supp + dose_c` modelini kurun.
# 2. `supp*dose_c` etkileşimli model ile ortak eğim varsayımını sınayın.
# 3. Altı hücre ortalaması modelini kurup doğrusal işlevsel biçim kısıtını test edin.
# 4. 0.5, 1 ve 2 mg'da OJ−VC farklarını aynı çoklu karşılaştırma ailesinde hesaplayın.
# 5. HC3 ve leave-one-out duyarlılığını model seçiminin yerine koymadan yorumlayın.
# 6. 3 mg'ı gözlenen ortak desteğin dışında ekstrapolasyon olarak işaretleyin.

# %%
# TODO: ortak eğim, etkileşim ve hücre modellerini kurun.
# TODO: model karşılaştırmalarını kendi hata MS paydalarıyla doğru hesaplayın.

# %%
# TODO: supp grupları için dose-len ilişkisini ve hücre ortalamalarını görselleştirin.

# %% [markdown]
# ## Akademik raporlama
# **Kovaryatın bilimsel rolü:** …
# **Ortak eğim testi:** …
# **İşlevsel biçim testi:** …
# **Koşullu OJ−VC farkları + aile GA:** …
# **HC3/duyarlılık:** …
# **Ortak destek ve genelleme sınırı:** …

# %% [markdown]
# Kontrol: `COZUMLER.md` → `beklenen.json` → `RAPORLAMA.md`. `spss-kontrol-listesi.md` SPSS çıktısı değildir.
