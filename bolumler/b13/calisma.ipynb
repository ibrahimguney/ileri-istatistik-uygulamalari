# %% [markdown]
# # Bölüm 13 — Ölçek Uyarlama ve Güvenirlik — Öğrenci Çalışma Defteri
#
# Bu çalışma ilk 100 BFI A/C maddesi alıntısına dayanır; Türkçe uyarlama çalışması değildir. Önce `VERI.md` ve `GOREVLER.md` dosyalarını okuyun.

# %%
from pathlib import Path
import numpy as np, pandas as pd, matplotlib.pyplot as plt
HERE=Path.cwd()
df=pd.read_csv(HERE/"bfi-ilk100-AC.csv")
display(df.head())
print(df.isna().sum())

# %% [markdown]
# ## Görevler
# 1. A1, C4, C5 ters puanlamasını yeni sütunlarda uygulayın.
# 2. A ve C için ham ve standartlaştırılmış Cronbach alfa hesaplayın.
# 3. Düzeltilmiş madde–geri kalan korelasyonlarını inceleyin.
# 4. Madde silindiğinde alfa değişimini içerik gerekçesinden bağımsız karar kuralı yapmayın.
# 5. Güvenirlik ile geçerlik/uyarlama kanıtını ayırın.

# %%
# TODO: ters puanlama ve alfa fonksiyonlarını yazın.
# Ham maddeleri değiştirmeyin.

# %%
# TODO: madde–geri kalan korelasyonlarını ve silinirse alfa değerlerini tablo/grafik olarak gösterin.

# %% [markdown]
# ## Akademik raporlama
# **Puanlama:** …
# **Eksik veri:** …
# **Alfa ve belirsizlik:** …
# **Madde analizi:** …
# **Geçerlik/uyarlama sınırı:** …

# %% [markdown]
# Kontrol: `COZUMLER.md` → `beklenen.json` → `RAPORLAMA.md`.
