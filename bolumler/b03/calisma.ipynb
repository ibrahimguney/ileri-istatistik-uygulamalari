# %% [markdown]
# # Bölüm 3 — Veri Hazırlama — Öğrenci Çalışma Defteri
#
# Önce `VERI.md` ve `GOREVLER.md` dosyalarını okuyun. `TODO` hücrelerini siz tamamlayın; en sonda `COZUMLER.md`, `beklenen.json` ve `RAPORLAMA.md` ile kontrol edin.
#
# **Akış:** Problem → Veri → Yöntem → Analiz → Görselleştirme → Yorum → Akademik raporlama

# %% [markdown]
# ## 1. Hazırlık

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
HERE=Path.cwd()
print("Klasör:", HERE)

# %% [markdown]
# ## 2. Veriyi tanıyın
# Ham veriyi değiştirmeden önce boyut, sütunlar ve eksik değerleri inceleyin.

# %%
df=pd.read_csv(HERE/"veri.csv")
display(df.head())
print(df.shape)
display(df.isna().sum().to_frame("eksik"))

# %% [markdown]
# ## 3. Görevler
# 1. Eksik değerleri sütun ve kayıt düzeyinde özetleyin.
# 2. A1, C4 ve C5 maddelerini 7−x ile ters puanlayıp yeni sütunlarda saklayın.
# 3. A ve C için 5/5 ve en az 4/5 kuralına göre ortalama puanlar üretin.
# 4. Veriyi uzun biçime çevirin ve kişi–madde anahtarının tekilliğini doğrulayın.

# %%
# TODO: eksikleri özetleyin; A1, C4, C5 için yeni ters puan sütunları ve 5/5-4/5 puanları üretin.

# %% [markdown]
# ## 4. Analiz alanınız
# Gerektikçe yeni kod hücreleri ekleyin.

# %%
# TODO: Analizinizi burada sürdürün.

# %% [markdown]
# ## 5. Görselleştirme
# Bölüme uygun en az bir grafik üretin ve grafiğin hangi soruya yanıt verdiğini yazın.

# %%
# TODO: grafik
# plt.show()

# %% [markdown]
# ## 6. Yorum
# Şunları kendi cümlelerinizle yanıtlayın: analiz birimi nedir; ana bulgu nedir; belirsizlik nasıl ifade edilir; hangi sınırlılık önemlidir; bu sonuçtan hangi iddia çıkarılamaz?

# %% [markdown]
# ### Akademik raporlama taslağım
#
# **Araştırma sorusu:** …
#
# **Yöntem ve veri:** …
#
# **Ana sonuç(lar):** …
#
# **Belirsizlik / etki büyüklüğü:** …
#
# **Sınırlılık:** …
#
# **Sonuç cümlesi:** …

# %% [markdown]
# ## 7. Kontrol
# 1. `GOREVLER.md`
# 2. `COZUMLER.md`
# 3. `beklenen.json`
# 4. `RAPORLAMA.md`
# 5. `analiz.py` / `analiz.R` yalnız son kontrol içindir.
