# %% [markdown]
# # Bölüm 10 — Parametrik Testler — Öğrenci Çalışma Defteri
#
# Önce `VERI.md` ve `GOREVLER.md` dosyalarını okuyun. Tasarım türünü testten önce belirleyin.

# %%
from pathlib import Path
import numpy as np, pandas as pd, matplotlib.pyplot as plt
from scipy import stats
HERE=Path.cwd()
sleep=pd.read_csv(HERE/"sleep.csv")
tooth=pd.read_csv(HERE/"ToothGrowth.csv")
display(sleep.head()); display(tooth.head())

# %% [markdown]
# ## Görevler
# 1. sleep verisinde tek örneklem ve eşli t testi problemlerini ayırın.
# 2. Eşli fark ortalaması, dz ve %95 GA'yı hesaplayın.
# 3. ToothGrowth dose=1 için OJ−VC Welch t testini uygulayın.
# 4. Varyans tanılarını 'varsayım kanıtı' gibi yorumlamayın.
# 5. Leave-one-pair-out duyarlılığını ana sonucun yerine değil yanında raporlayın.

# %%
# TODO: tek örneklem, eşli ve Welch testlerini doğru analiz birimleriyle uygulayın.

# %%
# TODO: eşli farkların veya iki grubun dağılımını uygun grafikle gösterin.

# %% [markdown]
# ## Akademik raporlama
# **Tasarım / analiz birimi:** …
# **Tahmin + %95 GA:** …
# **t, sd, p:** …
# **Etki büyüklüğü:** …
# **Tanı/duyarlılık ve sınırlılık:** …

# %% [markdown]
# Kontrol: `GOREVLER.md`, `COZUMLER.md`, `beklenen.json`, `RAPORLAMA.md`.
