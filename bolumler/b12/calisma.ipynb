# %% [markdown]
# # Bölüm 12 — Parametrik Olmayan Testler — Öğrenci Çalışma Defteri
#
# Önce `VERI.md` ve `GOREVLER.md` dosyalarını okuyun. Tasarım, bağımlılık yapısı, bağlar/sıfırlar ve p-değeri hesap yöntemini açıkça belirtin.

# %%
from pathlib import Path
import numpy as np, pandas as pd, matplotlib.pyplot as plt
from scipy import stats
HERE=Path.cwd()
sleep=pd.read_csv(HERE/"sleep.csv")
tooth=pd.read_csv(HERE/"ToothGrowth.csv")
rounding=pd.read_csv(HERE/"rounding-times.csv")
display(sleep.head()); display(tooth.head()); display(rounding.head())

# %% [markdown]
# ## Görevler
# 1. İki bağımsız grup için Mann–Whitney U ve rank-biserial etki büyüklüğü hesaplayın.
# 2. sleep eşli farklarında Wilcoxon signed-rank testini uygulayın.
# 3. ToothGrowth için Kruskal–Wallis ve uygun ikili karşılaştırmaları inceleyin.
# 4. RoundingTimes için Friedman ve Kendall W hesaplayın.
# 5. Kesin, asimptotik ve Monte Carlo p-değerlerini birbirine karıştırmayın.

# %%
# TODO: Mann–Whitney, Wilcoxon, Kruskal–Wallis ve Friedman analizlerini uygun veri yapılarında uygulayın.

# %%
# TODO: sıra veya eşli fark yapısını görünür kılan bir grafik üretin.

# %% [markdown]
# ## Akademik raporlama
# **Test/tasarım:** …
# **İstatistik ve p hesap yöntemi:** …
# **Etki büyüklüğü:** …
# **Çoklu karşılaştırma ailesi:** …
# **Sınırlılık:** …

# %% [markdown]
# Kontrol: `COZUMLER.md`, `beklenen.json`, `RAPORLAMA.md`.
