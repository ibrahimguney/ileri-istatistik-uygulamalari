# %% [markdown]
# # Bölüm 2 — Betimsel İstatistik — Öğrenci Çalışma Defteri
#
# Önce `VERI.md` ve `GOREVLER.md` dosyalarını okuyun. `TODO` hücrelerini siz tamamlayın; en sonda `COZUMLER.md`, `beklenen.json` ve `RAPORLAMA.md` ile kontrol edin.
#
# **Akış:** Problem → Veri → Yöntem → Analiz → Görselleştirme → Yorum → Akademik raporlama

# %% [markdown]
# ## 1. Hazırlık

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
HERE=Path.cwd()
print("Klasör:", HERE)

# %% [markdown]
# ## 2. Veriyi tanıyın
# Ham veriyi değiştirmeden önce boyut, sütunlar ve eksik değerleri inceleyin.

# %%
df=pd.read_csv(HERE/"veri.csv")
display(df.head())
print(df.shape)
display(df.isna().sum().to_frame("eksik"))

# %% [markdown]
# ## 3. Görevler
# 1. G1 ve G3 için n, ortalama, medyan, standart sapma, min–maks değerlerini hesaplayın.
# 2. G1 için Q1, Q3, IQR ve Tukey çitlerini hesaplayın; işaretlenen kayıtları belirleyin.
# 3. G3−G1 farkını oluşturun; artan/eşit/azalan kayıt sayılarını bulun.
# 4. İlk kaydı dışarıda bırakan duyarlılık sonucunu ana sonuçla karşılaştırın.

# %%
# TODO: G1 ve G3 betimsel özet, çeyrekler, IQR ve G3-G1 farkını hesaplayın.

# %% [markdown]
# ## 4. Analiz alanınız
# Gerektikçe yeni kod hücreleri ekleyin.

# %%
# TODO: Analizinizi burada sürdürün.

# %% [markdown]
# ## 5. Görselleştirme
# Bölüme uygun en az bir grafik üretin ve grafiğin hangi soruya yanıt verdiğini yazın.

# %%
# TODO: grafik
# plt.show()

# %% [markdown]
# ## 6. Yorum
# Şunları kendi cümlelerinizle yanıtlayın: analiz birimi nedir; ana bulgu nedir; belirsizlik nasıl ifade edilir; hangi sınırlılık önemlidir; bu sonuçtan hangi iddia çıkarılamaz?

# %% [markdown]
# ### Akademik raporlama taslağım
#
# **Araştırma sorusu:** …
#
# **Yöntem ve veri:** …
#
# **Ana sonuç(lar):** …
#
# **Belirsizlik / etki büyüklüğü:** …
#
# **Sınırlılık:** …
#
# **Sonuç cümlesi:** …

# %% [markdown]
# ## 7. Kontrol
# 1. `GOREVLER.md`
# 2. `COZUMLER.md`
# 3. `beklenen.json`
# 4. `RAPORLAMA.md`
# 5. `analiz.py` / `analiz.R` yalnız son kontrol içindir.
