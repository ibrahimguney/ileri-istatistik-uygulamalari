# %% [markdown]
# # Bölüm 16 — Yapısal Eşitlik Modeli — Öğrenci Çalışma Defteri
#
# Önce `VERI.md` ve `GOREVLER.md` dosyalarını okuyun. Ölçüm modeli ile yapısal modeli ayırın; uyum eşitliğini nedensel yön kanıtı olarak yorumlamayın.

# %%
from pathlib import Path
import numpy as np, pandas as pd, matplotlib.pyplot as plt
HERE=Path.cwd()
df=pd.read_csv(HERE/"bfi-ilk100-AC.csv")
display(df.head())

# %% [markdown]
# ## Görevler
# 1. A ve C ölçüm kısımlarını, ardından A→C yapısal yolunu tanımlayın.
# 2. Ham yol katsayısı, standartlaştırılmış beta ve yapısal R²'yi ayırın.
# 3. Wald ile olabilirlik oranı sonuçlarını karşılaştırın.
# 4. İleri ve ters yönlü eşdeğer modellerin aynı global uyumu verebilmesini inceleyin.
# 5. Kesitsel kovaryans yapısından nedensel yön seçilemeyeceğini rapora açıkça yazın.

# %%
# TODO: ölçüm + yapısal modeli kurun.
# TODO: ham yol, standart beta, R², Wald/LR sonuçlarını ayırın.

# %%
# TODO: ileri ve ters model sonuçlarını karşılaştıran bir tablo veya yol diyagramı özeti üretin.

# %% [markdown]
# ## Akademik raporlama
# **Ölçüm modeli:** …
# **Yapısal yol:** …
# **Standart beta / R²:** …
# **Wald ve LR:** …
# **Eşdeğer model ve nedensellik sınırı:** …

# %% [markdown]
# Kontrol: `COZUMLER.md`, `beklenen.json`, `RAPORLAMA.md`. `dfa_referans.py` bağımsız veri veya ikinci yazılım doğrulaması değildir; `amos-kontrol-listesi.md` çıktı değildir.
