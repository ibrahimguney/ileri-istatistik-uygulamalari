# %% [markdown]
# # Bölüm 9 — Aracılık ve Düzenleyicilik — Öğrenci Çalışma Defteri
#
# Bu bölümün verisi simülasyondur. Önce `VERI.md` ve `GOREVLER.md` dosyalarını okuyun; nedensel dil kullanmadan TODO hücrelerini tamamlayın.

# %%
from pathlib import Path
import numpy as np, pandas as pd, matplotlib.pyplot as plt
import statsmodels.api as sm
HERE=Path.cwd()
df=pd.read_csv(HERE/"veri.csv")
display(df.head())

# %% [markdown]
# ## Görevler
# 1. Aracılıkta a, b, c′ ve dolaylı etki ab'yi hesaplayın.
# 2. Satır bootstrap ile ab için yüzdelik %95 GA üretin.
# 3. Düzenleyicilik modeline X×W etkileşimini ekleyin.
# 4. W'nin ortalama ve ±1 SS düzeylerinde basit eğimleri hesaplayın.
# 5. Etkileşim testi ile tek tek basit eğim p-değerlerini karıştırmayın.

# %%
# TODO: a, b, c′, ab ve bootstrap GA
# TODO: X*W etkileşimi ve basit eğimler

# %%
# TODO: düzenleyicilik için tahmin çizgilerini görselleştirin.

# %% [markdown]
# ## Akademik raporlama
# **Aracılık yolları:** …
# **Dolaylı etki ve bootstrap GA:** …
# **Etkileşim ve basit eğimler:** …
# **Sınırlılık:** simülasyon verisi; bootstrap nedensellik kanıtı değildir.

# %% [markdown]
# Kontrol: `COZUMLER.md` → `beklenen.json` → `RAPORLAMA.md`.
