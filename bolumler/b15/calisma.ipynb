# %% [markdown]
# # Bölüm 15 — Doğrulayıcı Faktör Analizi — Öğrenci Çalışma Defteri
#
# Önce `VERI.md` ve `GOREVLER.md` dosyalarını okuyun. Bu bölümde ölçüm modeli, global uyum, yerel parametreler ve alternatif model karşılaştırmasını ayrı raporlayın.

# %%
from pathlib import Path
import numpy as np, pandas as pd, matplotlib.pyplot as plt
HERE=Path.cwd()
df=pd.read_csv(HERE/"bfi-ilk100-AC.csv")
display(df.head())

# %% [markdown]
# ## Görevler
# 1. Korelasyonlu iki faktör CFA modelinin serbest parametrelerini ve sd'sini yazın.
# 2. χ², CFI, RMSEA ve SRMR'yi birlikte yorumlayın.
# 3. Standartlaştırılmış yük, gösterge R² ve faktör korelasyonunu inceleyin.
# 4. A2 çapraz-yük alternatifini aynı veride seçilmiş model olarak karşılaştırın.
# 5. Sayısal yakınsama kontrollerini modelin bilimsel doğruluğuyla karıştırmayın.

# %%
# TODO: Bölümdeki model tanımını yeniden kurun.
# İsterseniz analiz.py fonksiyonlarını yalnız doğrulama için çağırın; önce kendi hesap/yorumunuzu yapın.

# %%
# TODO: model uyumlarını ve standartlaştırılmış yükleri tablo/grafik olarak özetleyin.

# %% [markdown]
# ## Akademik raporlama
# **Model ve sd:** …
# **Global uyum:** …
# **Yükler/R²/Phi:** …
# **Alternatif model:** …
# **Seçim ve doğrulama sınırı:** …

# %% [markdown]
# Kontrol: `COZUMLER.md` → `beklenen.json` → `RAPORLAMA.md`. `amos-kontrol-listesi.md` AMOS çıktısı değildir.
