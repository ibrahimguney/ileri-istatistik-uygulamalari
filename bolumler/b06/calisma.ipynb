# %% [markdown]
# # Bölüm 6 — Korelasyon — Öğrenci Çalışma Defteri
#
# Önce `VERI.md` ve `GOREVLER.md` dosyalarını okuyun. `TODO` hücrelerini siz tamamlayın; en sonda `COZUMLER.md`, `beklenen.json` ve `RAPORLAMA.md` ile kontrol edin.
#
# **Akış:** Problem → Veri → Yöntem → Analiz → Görselleştirme → Yorum → Akademik raporlama

# %% [markdown]
# ## 1. Hazırlık

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
HERE=Path.cwd()

# %% [markdown]
# ## 2. Veriyi tanıyın

# %%
df=pd.read_csv(HERE/"veri.csv")
display(df.head())
ana=df.iloc[:60].copy()
print(ana.shape)

# %% [markdown]
# ## 3. Görevler
# 1. İlk 60 kayıtta G1–G3 saçılımını inceleyin ve Pearson r hesaplayın.
# 2. Bağlı değerlere ortalama sıra vererek Spearman korelasyonunu hesaplayın.
# 3. Pearson için t testi ve Fisher-z yaklaşık %95 güven aralığını bulun.
# 4. Her seferinde bir kaydı dışarıda bırakarak Pearson duyarlılık aralığını hesaplayın.

# %%
# TODO: Pearson, Spearman, Fisher GA ve leave-one-out duyarlılığı

# %% [markdown]
# ## 4. Görselleştirme ve yorum

# %%
# TODO: G1-G3 saçılım grafiği ve gerekirse sıra grafiği

# %% [markdown]
# ## 5. Akademik raporlama taslağım
# **Araştırma sorusu:** …
#
# **Pearson / Spearman:** …
#
# **Belirsizlik:** …
#
# **Duyarlılık:** …
#
# **Nedensellik/genelleme sınırı:** …

# %% [markdown]
# ## 6. Kontrol
# `GOREVLER.md` → `COZUMLER.md` → `beklenen.json` → `RAPORLAMA.md`. `analiz.py` ve `analiz.R` yalnız son kontrol içindir.
