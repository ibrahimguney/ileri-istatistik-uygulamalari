# %% [markdown]
# # Bölüm 14 — Faktör Analizi — Öğrenci Çalışma Defteri
#
# Önce `VERI.md` ve `GOREVLER.md` dosyalarını okuyun. Faktörlenebilirlik, faktör sayısı, çıkarım, rotasyon ve artık yapısını tek bir karar zinciri olarak değerlendirin.

# %%
from pathlib import Path
import numpy as np, pandas as pd, matplotlib.pyplot as plt
from scipy import stats
HERE=Path.cwd()
df=pd.read_csv(HERE/"bfi-ilk100-AC.csv")
display(df.head())

# %% [markdown]
# ## Görevler
# 1. A1/C4/C5 puanlamasını uygulayıp ortak 97 kaydı oluşturun.
# 2. Pearson korelasyon matrisi, KMO ve Bartlett yaklaşımını inceleyin.
# 3. Özdeğerler ve paralel analiz mantığıyla 1/2/3 faktör adaylarını karşılaştırın.
# 4. İki faktörlü eğik çözümde örüntü, yapı ve Phi matrisini ayırın.
# 5. Artık matrisi ve RMSR ile model yeterliğini tartışın; daha düşük artık tek başına faktör sayısı kararı değildir.

# %%
# TODO: korelasyon/KMO/Bartlett ve faktör sayısı adımlarını kurun.
# TODO: iki faktörlü eğik çözümü inceleyin.

# %%
# TODO: scree/paralel analiz veya yük/artan yapı grafiği üretin.

# %% [markdown]
# ## Akademik raporlama
# **Örneklem ve puanlama:** …
# **KMO/Bartlett:** …
# **Faktör sayısı gerekçesi:** …
# **Örüntü/yapı/Phi:** …
# **Artıklar ve sınırlılık:** …

# %% [markdown]
# Kontrol: `COZUMLER.md`, `beklenen.json`, `RAPORLAMA.md`. Bu AFA aynı veride yapılmıştır; bağımsız CFA değildir.
