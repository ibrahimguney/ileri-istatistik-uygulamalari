# %% [markdown]
# # Bölüm 8 — Çoklu ve Lojistik Regresyon — Öğrenci Çalışma Defteri
#
# Önce `VERI.md` ve `GOREVLER.md` dosyalarını okuyun; TODO hücrelerini tamamlayın.

# %%
from pathlib import Path
import numpy as np, pandas as pd, matplotlib.pyplot as plt
import statsmodels.api as sm
HERE=Path.cwd()
df=pd.read_csv(HERE/"veri.csv")
display(df.head())

# %% [markdown]
# ## Görevler
# 1. G3 için G1 ve merkezlenmiş yaş ile çoklu OLS kurun.
# 2. VIF ile klasik/HC3 standart hataları karşılaştırın.
# 3. Bölümde tanımlanan başarı olayı için Logit modeli kurup OR hesaplayın.
# 4. .5 eşikte duyarlılık, özgüllük ve doğruluğu bulun.
# 5. İlk 60'la kurulan modeli son 20 kayda uygulayın; bunu dış doğrulama diye adlandırmayın.

# %%
# TODO: OLS ve Logit modellerini ayrı kurun.
# Yaşı merkezlerken hangi referans ortalamayı kullandığınızı yazın.

# %%
# TODO: olasılık dağılımı veya ROC benzeri uygun bir grafik üretin.

# %% [markdown]
# ## Akademik raporlama
# **OLS katsayıları / belirsizlik:** …
# **Logit OR / olasılık:** …
# **Eşik performansı:** …
# **Transfer 20 kayıt:** …
# **Sınırlılık:** OR olasılık oranı değildir; eşik ve başarı tanımı öğretim amaçlıdır.

# %% [markdown]
# Kontrol: `COZUMLER.md`, `beklenen.json`, `RAPORLAMA.md`; çözüm kodunu ancak kendi çalışmanızdan sonra açın.
