# %% [markdown]
# # Bölüm 11 — Varyans Analizi — Öğrenci Çalışma Defteri
#
# Önce `VERI.md` ve `GOREVLER.md` dosyalarını okuyun. Genel F testi, etki büyüklüğü, çoklu karşılaştırmalar ve etkileşimi ayrı adımlar olarak ele alın.

# %%
from pathlib import Path
import numpy as np, pandas as pd, matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
HERE=Path.cwd()
df=pd.read_csv(HERE/"ToothGrowth.csv")
display(df.head())

# %% [markdown]
# ## Görevler
# 1. OJ için tek yönlü ANOVA ve etki büyüklüğünü hesaplayın.
# 2. Tukey karşılaştırmalarını genel F testinden ayrı yorumlayın.
# 3. supp×dose iki faktörlü modeli kurup etkileşimi test edin.
# 4. Basit etkileri aynı çoklu karşılaştırma ailesi içinde raporlayın.
# 5. Kategorik dose modelini sayısal doğrusal eğim gibi yorumlamayın.

# %%
# TODO: tek yönlü ve iki faktörlü ANOVA modellerini kurun.

# %%
# TODO: hücre ortalamaları ve etkileşim grafiği üretin.

# %% [markdown]
# ## Akademik raporlama
# **Genel F ve etki büyüklüğü:** …
# **Post-hoc:** …
# **Etkileşim:** …
# **Basit etkiler:** …
# **Sınırlılık:** …

# %% [markdown]
# Kontrol: `COZUMLER.md` → `beklenen.json` → `RAPORLAMA.md`.
