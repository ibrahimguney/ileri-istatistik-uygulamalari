# %% [markdown]
# # Bölüm 5 — Güç Analizi ve Örneklem Planlama — Öğrenci Çalışma Defteri
#
# Önce `VERI.md` ve `GOREVLER.md` dosyalarını okuyun. `TODO` hücrelerini siz tamamlayın; en sonda `COZUMLER.md`, `beklenen.json` ve `RAPORLAMA.md` ile kontrol edin.
#
# **Akış:** Problem → Veri → Yöntem → Analiz → Görselleştirme → Yorum → Akademik raporlama

# %% [markdown]
# ## 1. Hazırlık

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
HERE=Path.cwd()
print("Klasör:", HERE)

# %% [markdown]
# ## 2. Veriyi tanıyın
# Ham veriyi değiştirmeden önce boyut, sütunlar ve eksik değerleri inceleyin.

# %%
df=pd.read_csv(HERE/"veri.csv")
display(df.head())
print(df.shape)
display(df.isna().sum().to_frame("eksik"))

# %% [markdown]
# ## 3. Görevler
# 1. Δ=5, σ=10 için d değerini hesaplayın ve planlama girdilerini açıkça yazın.
# 2. İki bağımsız grup, α=.05, iki yönlü ve güç=.80 için minimum n/grup değerini bulun.
# 3. d=.20, .30, .50, .80 senaryolarında gerekli örneklem büyüklüğünü karşılaştırın.
# 4. %15 kayıp için beklenen sayı düzeltmesi ile hedef tutulma olasılığı yaklaşımını ayırın.

# %%
from scipy import stats, optimize
# TODO: d=Δ/σ; iki bağımsız grup için güç ve minimum n/grup hesabını kurun.

# %% [markdown]
# ## 4. Analiz alanınız
# Gerektikçe yeni kod hücreleri ekleyin.

# %%
# TODO: Analizinizi burada sürdürün.

# %% [markdown]
# ## 5. Görselleştirme
# Bölüme uygun en az bir grafik üretin ve grafiğin hangi soruya yanıt verdiğini yazın.

# %%
# TODO: grafik
# plt.show()

# %% [markdown]
# ## 6. Yorum
# Şunları kendi cümlelerinizle yanıtlayın: analiz birimi nedir; ana bulgu nedir; belirsizlik nasıl ifade edilir; hangi sınırlılık önemlidir; bu sonuçtan hangi iddia çıkarılamaz?

# %% [markdown]
# ### Akademik raporlama taslağım
#
# **Araştırma sorusu:** …
#
# **Yöntem ve veri:** …
#
# **Ana sonuç(lar):** …
#
# **Belirsizlik / etki büyüklüğü:** …
#
# **Sınırlılık:** …
#
# **Sonuç cümlesi:** …

# %% [markdown]
# ## 7. Kontrol
# 1. `GOREVLER.md`
# 2. `COZUMLER.md`
# 3. `beklenen.json`
# 4. `RAPORLAMA.md`
# 5. `analiz.py` / `analiz.R` yalnız son kontrol içindir.
